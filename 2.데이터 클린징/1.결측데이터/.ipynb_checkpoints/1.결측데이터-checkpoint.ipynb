# %%
### 결측 데이터

#### 결측치
* 누락되거나 문제가 있는 데이터를 의미한다
* 데이터 입력시 인코딩 또는 네트워크 문제, 공란 등의 이유로 무엇인지 판단하기 어려운 데이터
* 판다스에서는 결측값을 NaN(Not a Number)으로 표기하며 None, 공백도 결측치로 사용된다

#### 결측치 처리 방법
* 결측치 확인
* 결측치 대체 / 제거
* 결측치 반영 확인

#### 결측치 확인 함수
* isnull() : 결측치 True, 유효 데이터 False 반환
* notnull() : 결측치 False, 유효 데이터 True 반환

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data_set/2.데이터 클린징/nan.csv")
df
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df.head(3)
df.tail()
# Out:
#    data1  data2  data3  nan_1  nan_2
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df.isnull() #결측 데이터 True
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0  False  False  False  False   True
# 1  False  False  False   True   True
# 2  False  False  False  False   True
# 3  False  False  False   True   True
# 4  False  False  False  False   True
# 5  False  False  False   True  False

# %%
df.isnull().sum()
# Out:
# data1    0
# data2    0
# data3    0
# nan_1    3
# nan_2    5
# dtype: int64

# %%
df.shape
# Out:
# (6, 5)

# %%
df.notnull() #결측지 False
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0   True   True   True   True  False
# 1   True   True   True  False  False
# 2   True   True   True   True  False
# 3   True   True   True  False  False
# 4   True   True   True   True  False
# 5   True   True   True  False   True

# %%
df.notnull().sum() #True에 대한 합
# Out:
# data1    6
# data2    6
# data3    6
# nan_1    3
# nan_2    1
# dtype: int64

# %%
df.shape # 행,열
# Out:
# (6, 5)

# %%
df
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df.dropna() # axis = 0
# Out:
# Empty DataFrame
# Columns: [data1, data2, data3, nan_1, nan_2]
# Index: []

# %%
df.dropna(axis = 1) # 열(nan 포함된) 삭제
# Out:
#    data1  data2  data3
# 0      0      1      2
# 1      3      4      2
# 2      3      4      8
# 3      9     10     11
# 4     12     10     14
# 5     15     16     17

# %%
df
df['nan_1']
df['nan_1'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# Name: nan_1, dtype: bool

# %%
df[df['nan_1'].isnull()] # nan_1이 nan인 데이터
# Out:
#    data1  data2  data3  nan_1  nan_2
# 1      3      4      2    NaN    NaN
# 3      9     10     11    NaN    NaN
# 5     15     16     17    NaN    1.0

# %%
df[df['nan_1'].notnull()] # nan_1이 nan이 아닌 데이터
df.loc[df['nan_1'].notnull()]
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 2      3      4      8    2.4    NaN
# 4     12     10     14    1.2    NaN

# %%
df
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df.fillna(value=100) #결측치가 있는 공간을 특정 데이터로 채우겠다.
df.fillna(0)
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    0.0
# 1      3      4      2    0.0    0.0
# 2      3      4      8    2.4    0.0
# 3      9     10     11    0.0    0.0
# 4     12     10     14    1.2    0.0
# 5     15     16     17    0.0    1.0

# %%
df.mean() # 각 열의 평균값
# Out:
# data1    7.000000
# data2    7.500000
# data3    9.000000
# nan_1    1.766667
# nan_2    1.000000
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#    data1  data2  data3     nan_1  nan_2
# 0      0      1      2  1.700000    1.0
# 1      3      4      2  1.766667    1.0
# 2      3      4      8  2.400000    1.0
# 3      9     10     11  1.766667    1.0
# 4     12     10     14  1.200000    1.0
# 5     15     16     17  1.766667    1.0

# %%
data = { 'v1':[12, 12, 17, 1, 3, 6, 6, 7, 10],
         'v2':[1, 3, 6, 6, 6, 7, 7, 12, 12]
       }
df_test = pd.DataFrame(data)
df_test
# Out:
#    v1  v2
# 0  12   1
# 1  12   3
# 2  17   6
# 3   1   6
# 4   3   6
# 5   6   7
# 6   6   7
# 7   7  12
# 8  10  12

# %%
df_test.median()
# Out:
# v1    7.0
# v2    6.0
# dtype: float64

# %%
df_test['v1'].sort_values()
# Out:
# 3     1
# 4     3
# 5     6
# 6     6
# 7     7
# 8    10
# 0    12
# 1    12
# 2    17
# Name: v1, dtype: int64

# %%
df_test.mode() # 최빈값
# Out:
#    v1   v2
# 0   6  6.0
# 1  12  NaN

# %%
df_test['v1'].value_counts()
# Out:
# v1
# 12    2
# 6     2
# 17    1
# 1     1
# 3     1
# 7     1
# 10    1
# Name: count, dtype: int64

# %%
df_test.mode()
df_test['v2'].mode()
# Out:
# 0    6
# Name: v2, dtype: int64

# %%
df
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df.median()
# Out:
# data1    6.0
# data2    7.0
# data3    9.5
# nan_1    1.7
# nan_2    1.0
# dtype: float64

# %%
df.fillna(df.median())
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    1.0
# 1      3      4      2    1.7    1.0
# 2      3      4      8    2.4    1.0
# 3      9     10     11    1.7    1.0
# 4     12     10     14    1.2    1.0
# 5     15     16     17    1.7    1.0

# %%
df.mode()
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0    3.0    4.0    2.0    1.2    1.0
# 1    NaN   10.0    NaN    1.7    NaN
# 2    NaN    NaN    NaN    2.4    NaN

# %%
df.fillna(df.mode())
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    1.0
# 1      3      4      2    1.7    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df.mode().loc[0]
# Out:
# data1    3.0
# data2    4.0
# data3    2.0
# nan_1    1.2
# nan_2    1.0
# Name: 0, dtype: float64

# %%
df.fillna(df.mode().loc[0])
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    1.0
# 1      3      4      2    1.2    1.0
# 2      3      4      8    2.4    1.0
# 3      9     10     11    1.2    1.0
# 4     12     10     14    1.2    1.0
# 5     15     16     17    1.2    1.0

# %%
df
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df.ffill() # 위에서부터 실행하는데 내려오면서 그 전에 있는 값으로 nan을 채운다.
# 처음부터 시작 -> nan 값 전 값으로 채움
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    1.7    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    2.4    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    1.2    1.0

# %%
df.bfill() # 아래서부터 시작 -> 전에 있는 값으로 nan을 채움
# 아래서 위로 -> nan 값 전값으로 치환
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    1.0
# 1      3      4      2    2.4    1.0
# 2      3      4      8    2.4    1.0
# 3      9     10     11    1.2    1.0
# 4     12     10     14    1.2    1.0
# 5     15     16     17    NaN    1.0

# %%
df
# Out:
#    data1  data2  data3  nan_1  nan_2
# 0      0      1      2    1.7    NaN
# 1      3      4      2    NaN    NaN
# 2      3      4      8    2.4    NaN
# 3      9     10     11    NaN    NaN
# 4     12     10     14    1.2    NaN
# 5     15     16     17    NaN    1.0

# %%
df['data2'].unique() # 중복없이 값만 뽑는다.
# Out:
# array([ 1,  4, 10, 16])
