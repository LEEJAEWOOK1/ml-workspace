# %% [markdown]
# ### pandas
# - 특정 데이터를 DataFrame형식으로 처리

# %%
import pandas as pd

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
print(df['name'])
df.age # 그냥 쓰면 마지막 꺼 출력(중간거 출력하고 싶으면 print 사용)
# Out:
# 0     Kim
# 1     Cho
# 2    Choi
# 3      jo
# Name: name, dtype: object
# 0    20
# 1    30
# 2    40
# 3    50
# Name: age, dtype: int64

# %%
#df[["name", "age"]]
df[["name"]]
# Out:
#    name
# 0   Kim
# 1   Cho
# 2  Choi
# 3    jo

# %%
df[1 : 3]#['name'] # 슬라이싱
#df[1 : ] #1 ~ 끝까지
# Out:
#    name  score grade  age
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40

# %%
# index(조건), column(조건)
df.loc[1 : 3, "name"]  = "aaaa" # 그 숫자까지 출력해라
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1  aaaa   95.0     A   30
# 2  aaaa   90.5     B   40
# 3  aaaa   85.7     B   50

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.loc[ : , ['name','age']]
# Out:
#    name  age
# 0   Kim   20
# 1   Cho   30
# 2  Choi   40
# 3    jo   50

# %%
df.loc[ : ]
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.loc[df['grade'] == 'A', 'grade'] # grade가 A인것 출력(grade만 뽑아온다)
# Out:
# 0    A
# 1    A
# Name: grade, dtype: object

# %%
df.loc[df['grade'] == 'A', 'grade'] = 'CCC'
df
# Out:
#    name  score grade  age
# 0   Kim  100.0   CCC   20
# 1   Cho   95.0   CCC   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df.drop(2) # 삭제
# Out:
#   name  score grade  age
# 0  Kim  100.0     A   20
# 1  Cho   95.0     A   30
# 3   jo   85.7     B   50

# %%
df
# Out:
#    name  score grade  age
# 0   Kim  100.0   CCC   20
# 1   Cho   95.0   CCC   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df = df.drop(2)
df
# Out:
#   name  score grade  age
# 0  Kim  100.0   CCC   20
# 1  Cho   95.0   CCC   30
# 3   jo   85.7     B   50

# %%
df.drop(1, inplace = True) # 삭제 후 바로 반영
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df.drop(1, inplace = True) # 삭제 후 바로 반영
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.drop(0, axis=0, inplace=True)
df
# Out:
#   name  score grade  age
# 3   jo   85.7     B   50

# %%
df.drop('name', axis=1, inplace=True)
df
# Out:
#    score grade  age
# 3   85.7     B   50

# %%
df = pd.read_csv("../data_set/1.pandas/1.pandas.csv")
df
# Out:
#    name  score grade  age
# 0   Kim  100.0     A   20
# 1   Cho   95.0     A   30
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
df['score'] < 95
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: score, dtype: bool

# %%
#df[df['score'] < 95]
df.loc[df['score'] < 95]
# Out:
#    name  score grade  age
# 2  Choi   90.5     B   40
# 3    jo   85.7     B   50

# %%
#df[df['score'] < 95]['name']
df.loc[df['score'] < 95, 'name']
# Out:
# 2    Choi
# 3      jo
# Name: name, dtype: object

# %%
#df[df['score'] < 95][['name','age']]
df.loc[df['score'] < 95, ['name','age']]
# Out:
#    name  age
# 2  Choi   40
# 3    jo   50

# %%
df.columns
# Out:
# Index(['name', 'score', 'grade', 'age'], dtype='object')

# %%
df.values
# Out:
# array([['Kim', 100.0, 'A', 20],
#        ['Cho', 95.0, 'A', 30],
#        ['Choi', 90.5, 'B', 40],
#        ['jo', 85.7, 'B', 50]], dtype=object)

# %%
df.dtypes
# Out:
# name      object
# score    float64
# grade     object
# age        int64
# dtype: object

# %%
df['grade']
# Out:
# 0    A
# 1    A
# 2    B
# 3    B
# Name: grade, dtype: object

# %%
df['grade'].isin(['A']) # 해당 값이 있는지 확인
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: grade, dtype: bool

# %%
df[df['grade'].isin(['A'])]
# Out:
#   name  score grade  age
# 0  Kim  100.0     A   20
# 1  Cho   95.0     A   30

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
index_name = ['김', '이', '박', '조']
df.index = index_name

# %%
df
# Out:
#    name  score grade  age
# 김   Kim  100.0     A   20
# 이   Cho   95.0     A   30
# 박  Choi   90.5     B   40
# 조    jo   85.7     B   50

# %%
df.index
# Out:
# Index(['김', '이', '박', '조'], dtype='object')

# %%
df[1:3]
# Out:
#    name  score grade  age
# 이   Cho   95.0     A   30
# 박  Choi   90.5     B   40

# %%
df['이' : '조']
# Out:
#    name  score grade  age
# 이   Cho   95.0     A   30
# 박  Choi   90.5     B   40
# 조    jo   85.7     B   50
